# %%
import os
import json
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import torch
from datasets import DatasetDict, Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    EarlyStoppingCallback,
)
import evaluate
import pickle

warnings.filterwarnings("ignore")

# %%
train_path = "./output/02_train.jsonl"
val_path = "./output/02_val.jsonl"
test_path = "./output/02_test.jsonl"

# %%
train_data = pd.read_json(train_path, lines=True)
val_data = pd.read_json(val_path, lines=True)
test_data = pd.read_json(test_path, lines=True)

# %%
train_data.head()
# Out:
#    row_id                                           headline     category  \
# 0  153996  Poodle Cat: New Breed Of Feline Is Adorably Fl...  ENVIRONMENT
# 1   80071  ESPN Reporter Blasts Cowboys' Sponsors After G...       SPORTS
# 2  151401  Palo Verde Beetles, Huge Horny Bugs, Descend O...  ENVIRONMENT
# 3  177136                      The Hope for Brave New Worlds     WELLNESS
# 4   97560                         How Many Likes Are Enough?     WELLNESS
#
#                                        text_combined
# 0  Poodle Cat: New Breed Of Feline Is Adorably Fl...
# 1  ESPN Reporter Blasts Cowboys' Sponsors After G...
# 2  Palo Verde Beetles, Huge Horny Bugs, Descend O...
# 3  The Hope for Brave New Worlds [SEP] The discov...
# 4  How Many Likes Are Enough? [SEP] When we seek ...

# %%
print(f"Train Shape: {train_data.shape}")
print(f"Val Shape: {val_data.shape}")
print(f"Test Shape: {test_data.shape}")
# Out:
# Train Shape: (129006, 4)
# Val Shape: (32252, 4)
# Test Shape: (40315, 4)

# %%
with open(
    "./artifacts/02_y_encoder.pkl",
    "rb",
) as f:
    y_encoder = pickle.load(f)

# %%
train_data["labels"] = train_data["category"].apply(
    lambda x: y_encoder.transform([x])[0]
)
val_data["labels"] = val_data["category"].apply(lambda x: y_encoder.transform([x])[0])
test_data["labels"] = test_data["category"].apply(lambda x: y_encoder.transform([x])[0])

# %%
train_data.head()
# Out:
#    row_id                                           headline     category  \
# 0  153996  Poodle Cat: New Breed Of Feline Is Adorably Fl...  ENVIRONMENT
# 1   80071  ESPN Reporter Blasts Cowboys' Sponsors After G...       SPORTS
# 2  151401  Palo Verde Beetles, Huge Horny Bugs, Descend O...  ENVIRONMENT
# 3  177136                      The Hope for Brave New Worlds     WELLNESS
# 4   97560                         How Many Likes Are Enough?     WELLNESS
#
#                                        text_combined  labels
# 0  Poodle Cat: New Breed Of Feline Is Adorably Fl...       7
# 1  ESPN Reporter Blasts Cowboys' Sponsors After G...      17
# 2  Palo Verde Beetles, Huge Horny Bugs, Descend O...       7
# 3  The Hope for Brave New Worlds [SEP] The discov...      22
# 4  How Many Likes Are Enough? [SEP] When we seek ...      22

# %%
data = DatasetDict(
    {
        "train": Dataset.from_pandas(train_data[["row_id", "headline", "labels"]]),
        "validation": Dataset.from_pandas(val_data[["row_id", "headline", "labels"]]),
        "test": Dataset.from_pandas(test_data[["row_id", "headline", "labels"]]),
    }
)

data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['row_id', 'headline', 'labels'],
#         num_rows: 129006
#     })
#     validation: Dataset({
#         features: ['row_id', 'headline', 'labels'],
#         num_rows: 32252
#     })
#     test: Dataset({
#         features: ['row_id', 'headline', 'labels'],
#         num_rows: 40315
#     })
# })

# %%
data["train"]["labels"][:5]
# Out:
# [7, 17, 7, 22, 22]

# %% [markdown]
# ## Tokenize

# %%
MODEL_NAME = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
def preprocess_data(examples):
    # take a batch of texts
    text = examples["headline"]
    # encode them
    encoding = tokenizer(text, padding="max_length", truncation=True, max_length=256)

    # add labels
    encoding["labels"] = torch.Tensor(examples["labels"])

    return encoding

# %%
encoded_dataset = data.map(
    preprocess_data, batched=True, remove_columns=data["train"].column_names
)
# Out:
# ...
# Map:   0%|          | 0/40315 [00:00<?, ? examples/s]

# %%
import os

os.getcwd()
# Out:
# '/Users/philip.juachon/Desktop/Personal Learning/Deep Learning/final-project'

# %%
encoded_dataset.save_to_disk("title_classifier_encoded_dataset_headlines_only.hf")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/40315 [00:00<?, ? examples/s]
